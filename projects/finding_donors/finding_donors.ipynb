# %% [markdown]
# # Machine Learning Engineer Nanodegree
# ## Supervised Learning
# ## Project: Finding Donors for *CharityML*

# %% [markdown]
# Welcome to the second project of the Machine Learning Engineer Nanodegree! In this notebook, some template code has already been provided for you, and it will be your job to implement the additional functionality necessary to successfully complete this project. Sections that begin with **'Implementation'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `'TODO'` statement. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Please specify WHICH VERSION OF PYTHON you are using when submitting this notebook. Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ## Getting Started
#
# In this project, you will employ several supervised algorithms of your choice to accurately model individuals' income using data collected from the 1994 U.S. Census. You will then choose the best candidate algorithm from preliminary results and further optimize this algorithm to best model the data. Your goal with this implementation is to construct a model that accurately predicts whether an individual makes more than $50,000. This sort of task can arise in a non-profit setting, where organizations survive on donations.  Understanding an individual's income can help a non-profit better understand how large of a donation to request, or whether or not they should reach out to begin with.  While it can be difficult to determine an individual's general income bracket directly from public sources, we can (as we will see) infer this value from other publically available features.
#
# The dataset for this project originates from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Census+Income). The datset was donated by Ron Kohavi and Barry Becker, after being published in the article _"Scaling Up the Accuracy of Naive-Bayes Classifiers: A Decision-Tree Hybrid"_. You can find the article by Ron Kohavi [online](https://www.aaai.org/Papers/KDD/1996/KDD96-033.pdf). The data we investigate here consists of small changes to the original dataset, such as removing the `'fnlwgt'` feature and records with missing or ill-formatted entries.

# %% [markdown]
# ----
# ## Exploring the Data
# Run the code cell below to load necessary Python libraries and load the census data. Note that the last column from this dataset, `'income'`, will be our target label (whether an individual makes more than, or at most, $50,000 annually). All other columns are features about each individual in the census database.

# %%
# Import libraries necessary for this project
# Python 3.6.4
import numpy as np
import pandas as pd
from time import time
from IPython.display import display # Allows the use of display() for DataFrames

# Import supplementary visualization code visuals.py
import visuals as vs

# Pretty display for notebooks
# %matplotlib inline

# Load the Census dataset
data = pd.read_csv("census.csv")

# Success - Display the first record
display(data.head(n=1))
# Out:
#    age   workclass education_level  education-num  marital-status  \
# 0   39   State-gov       Bachelors           13.0   Never-married
#
#       occupation    relationship    race    sex  capital-gain  capital-loss  \
# 0   Adm-clerical   Not-in-family   White   Male        2174.0           0.0
#
#    hours-per-week  native-country income
# 0            40.0   United-States  <=50K

# %% [markdown]
# ### Implementation: Data Exploration
# A cursory investigation of the dataset will determine how many individuals fit into either group, and will tell us about the percentage of these individuals making more than \$50,000. In the code cell below, you will need to compute the following:
# - The total number of records, `'n_records'`
# - The number of individuals making more than \$50,000 annually, `'n_greater_50k'`.
# - The number of individuals making at most \$50,000 annually, `'n_at_most_50k'`.
# - The percentage of individuals making more than \$50,000 annually, `'greater_percent'`.
#
# ** HINT: ** You may need to look at the table above to understand how the `'income'` entries are formatted.

# %%
data['income'].value_counts()
# Out:
# <=50K    34014
# >50K     11208
# Name: income, dtype: int64

# %%
# TODO: Total number of records
n_records = len(data)

# TODO: Number of records where individual's income is more than $50,000
n_greater_50k = data['income'].value_counts()[1]

# TODO: Number of records where individual's income is at most $50,000
n_at_most_50k = data['income'].value_counts()[0]

# TODO: Percentage of individuals whose income is more than $50,000
greater_percent = n_greater_50k / n_records

# Print the results
print("Total number of records: {}".format(n_records))
print("Individuals making more than $50,000: {}".format(n_greater_50k))
print("Individuals making at most $50,000: {}".format(n_at_most_50k))
print("Percentage of individuals making more than $50,000: {:.2f}%".format(100*greater_percent))
# Out:
# Total number of records: 45222
# Individuals making more than $50,000: 11208
# Individuals making at most $50,000: 34014
# Percentage of individuals making more than $50,000: 24.78%

# %% [markdown]
# ** Featureset Exploration **
#
# * **age**: continuous.
# * **workclass**: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * **education**: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * **education-num**: continuous.
# * **marital-status**: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * **occupation**: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * **relationship**: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * **race**: Black, White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other.
# * **sex**: Female, Male.
# * **capital-gain**: continuous.
# * **capital-loss**: continuous.
# * **hours-per-week**: continuous.
# * **native-country**: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %% [markdown]
# ----
# ## Preparing the Data
# Before data can be used as input for machine learning algorithms, it often must be cleaned, formatted, and restructured — this is typically known as **preprocessing**. Fortunately, for this dataset, there are no invalid or missing entries we must deal with, however, there are some qualities about certain features that must be adjusted. This preprocessing can help tremendously with the outcome and predictive power of nearly all learning algorithms.

# %% [markdown]
# ### Transforming Skewed Continuous Features
# A dataset may sometimes contain at least one feature whose values tend to lie near a single number, but will also have a non-trivial number of vastly larger or smaller values than that single number.  Algorithms can be sensitive to such distributions of values and can underperform if the range is not properly normalized. With the census dataset two features fit this description: '`capital-gain'` and `'capital-loss'`.
#
# Run the code cell below to plot a histogram of these two features. Note the range of the values present and how they are distributed.

# %%
# Split the data into features and target label
income_raw = data['income']
features_raw = data.drop('income', axis = 1)

# Visualize skewed continuous features of original data
vs.distribution(data)

# %% [markdown]
# For highly-skewed feature distributions such as `'capital-gain'` and `'capital-loss'`, it is common practice to apply a <a href="https://en.wikipedia.org/wiki/Data_transformation_(statistics)">logarithmic transformation</a> on the data so that the very large and very small values do not negatively affect the performance of a learning algorithm. Using a logarithmic transformation significantly reduces the range of values caused by outliers. Care must be taken when applying this transformation however: The logarithm of `0` is undefined, so we must translate the values by a small amount above `0` to apply the the logarithm successfully.
#
# Run the code cell below to perform a transformation on the data and visualize the results. Again, note the range of values and how they are distributed.

# %%
# Log-transform the skewed features
skewed = ['capital-gain', 'capital-loss']
features_log_transformed = pd.DataFrame(data = features_raw)
features_log_transformed[skewed] = features_raw[skewed].apply(lambda x: np.log(x + 1))

# Visualize the new log distributions
vs.distribution(features_log_transformed, transformed = True)

# %% [markdown]
# ### Normalizing Numerical Features
# In addition to performing transformations on features that are highly skewed, it is often good practice to perform some type of scaling on numerical features. Applying a scaling to the data does not change the shape of each feature's distribution (such as `'capital-gain'` or `'capital-loss'` above); however, normalization ensures that each feature is treated equally when applying supervised learners. Note that once scaling is applied, observing the data in its raw form will no longer have the same original meaning, as exampled below.
#
# Run the code cell below to normalize each numerical feature. We will use [`sklearn.preprocessing.MinMaxScaler`](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html) for this.

# %%
# Import sklearn.preprocessing.StandardScaler
from sklearn.preprocessing import MinMaxScaler

# Initialize a scaler, then apply it to the features
scaler = MinMaxScaler() # default=(0, 1)
numerical = ['age', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']

features_log_minmax_transform = pd.DataFrame(data = features_log_transformed)
features_log_minmax_transform[numerical] = scaler.fit_transform(features_log_transformed[numerical])

# Show an example of a record with scaling applied
display(features_log_minmax_transform.head(n = 5))
# Out:
#         age          workclass education_level  education-num  \
# 0  0.301370          State-gov       Bachelors       0.800000
# 1  0.452055   Self-emp-not-inc       Bachelors       0.800000
# 2  0.287671            Private         HS-grad       0.533333
# 3  0.493151            Private            11th       0.400000
# 4  0.150685            Private       Bachelors       0.800000
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country
# 0      0.667492           0.0        0.397959   United-States
# 1      0.000000           0.0        0.122449   United-States
# 2      0.000000           0.0        0.397959   United-States
# 3      0.000000           0.0        0.397959   United-States
# 4      0.000000           0.0        0.397959            Cuba

# %% [markdown]
# ### Implementation: Data Preprocessing
#
# From the table in **Exploring the Data** above, we can see there are several features for each record that are non-numeric. Typically, learning algorithms expect input to be numeric, which requires that non-numeric features (called *categorical variables*) be converted. One popular way to convert categorical variables is by using the **one-hot encoding** scheme. One-hot encoding creates a _"dummy"_ variable for each possible category of each non-numeric feature. For example, assume `someFeature` has three possible entries: `A`, `B`, or `C`. We then encode this feature into `someFeature_A`, `someFeature_B` and `someFeature_C`.
#
# |   | someFeature |                    | someFeature_A | someFeature_B | someFeature_C |
# | :-: | :-: |                            | :-: | :-: | :-: |
# | 0 |  B  |  | 0 | 1 | 0 |
# | 1 |  C  | ----> one-hot encode ----> | 0 | 0 | 1 |
# | 2 |  A  |  | 1 | 0 | 0 |
#
# Additionally, as with the non-numeric features, we need to convert the non-numeric target label, `'income'` to numerical values for the learning algorithm to work. Since there are only two possible categories for this label ("<=50K" and ">50K"), we can avoid using one-hot encoding and simply encode these two categories as `0` and `1`, respectively. In code cell below, you will need to implement the following:
#  - Use [`pandas.get_dummies()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html?highlight=get_dummies#pandas.get_dummies) to perform one-hot encoding on the `'features_log_minmax_transform'` data.
#  - Convert the target label `'income_raw'` to numerical entries.
#    - Set records with "<=50K" to `0` and records with ">50K" to `1`.

# %%
# TODO: One-hot encode the 'features_log_minmax_transform' data using pandas.get_dummies()
features_final = pd.get_dummies(features_log_minmax_transform)

# TODO: Encode the 'income_raw' data to numerical values
income = income_raw.map({'<=50K': 0, '>50K': 1})

# Print the number of features after one-hot encoding
encoded = list(features_final.columns)
print("{} total features after one-hot encoding.".format(len(encoded)))

# Uncomment the following line to see the encoded feature names
print(encoded)
# Out:
# 103 total features after one-hot encoding.
# ['age', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week', 'workclass_ Federal-gov', 'workclass_ Local-gov', 'workclass_ Private', 'workclass_ Self-emp-inc', 'workclass_ Self-emp-not-inc', 'workclass_ State-gov', 'workclass_ Without-pay', 'education_level_ 10th', 'education_level_ 11th', 'education_level_ 12th', 'education_level_ 1st-4th', 'education_level_ 5th-6th', 'education_level_ 7th-8th', 'education_level_ 9th', 'education_level_ Assoc-acdm', 'education_level_ Assoc-voc', 'education_level_ Bachelors', 'education_level_ Doctorate', 'education_level_ HS-grad', 'education_level_ Masters', 'education_level_ Preschool', 'education_level_ Prof-school', 'education_level_ Some-college', 'marital-status_ Divorced', 'marital-status_ Married-AF-spouse', 'marital-status_ Married-civ-spouse', 'marital-status_ Married-spouse-absent', 'marital-status_ Never-married', 'marital-status_ Separated', 'marital-status_ Widowed', 'occupation_ Adm-clerical', 'occupation_ Armed-Forces', 'occupation_ Craft-repair', 'occupation_ Exec-managerial', 'occupation_ Farming-fishing', 'occupation_ Handlers-cleaners', 'occupation_ Machine-op-inspct', 'occupation_ Other-service', 'occupation_ Priv-house-serv', 'occupation_ Prof-specialty', 'occupation_ Protective-serv', 'occupation_ Sales', 'occupation_ Tech-support', 'occupation_ Transport-moving', 'relationship_ Husband', 'relationship_ Not-in-family', 'relationship_ Other-relative', 'relationship_ Own-child', 'relationship_ Unmarried', 'relationship_ Wife', 'race_ Amer-Indian-Eskimo', 'race_ Asian-Pac-Islander', 'race_ Black', 'race_ Other', 'race_ White', 'sex_ Female', 'sex_ Male', 'native-country_ Cambodia', 'native-country_ Canada', 'native-country_ China', 'native-country_ Columbia', 'native-country_ Cuba', 'native-country_ Dominican-Republic', 'native-country_ Ecuador', 'native-country_ El-Salvador', 'native-country_ England', 'native-country_ France', 'native-country_ Germany', 'native-country_ Greece', 'native-country_ Guatemala', 'native-country_ Haiti', 'native-country_ Holand-Netherlands', 'native-country_ Honduras', 'native-country_ Hong', 'native-country_ Hungary', 'native-country_ India', 'native-country_ Iran', 'native-country_ Ireland', 'native-country_ Italy', 'native-country_ Jamaica', 'native-country_ Japan', 'native-country_ Laos', 'native-country_ Mexico', 'native-country_ Nicaragua', 'native-country_ Outlying-US(Guam-USVI-etc)', 'native-country_ Peru', 'native-country_ Philippines', 'native-country_ Poland', 'native-country_ Portugal', 'native-country_ Puerto-Rico', 'native-country_ Scotland', 'native-country_ South', 'native-country_ Taiwan', 'native-country_ Thailand', 'native-country_ Trinadad&Tobago', 'native-country_ United-States', 'native-country_ Vietnam', 'native-country_ Yugoslavia']

# %% [markdown]
# ### Shuffle and Split Data
# Now all _categorical variables_ have been converted into numerical features, and all numerical features have been normalized. As always, we will now split the data (both features and their labels) into training and test sets. 80% of the data will be used for training and 20% for testing.
#
# Run the code cell below to perform this split.

# %%
# Import train_test_split
from sklearn.model_selection import train_test_split

# Split the 'features' and 'income' data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_final, 
                                                    income, 
                                                    test_size = 0.2, 
                                                    random_state = 0,
                                                    shuffle=True)

# Show the results of the split
print("Training set has {} samples.".format(X_train.shape[0]))
print("Testing set has {} samples.".format(X_test.shape[0]))
# Out:
# Training set has 36177 samples.
# Testing set has 9045 samples.

# %% [markdown]
# ----
# ## Evaluating Model Performance
# In this section, we will investigate four different algorithms, and determine which is best at modeling the data. Three of these algorithms will be supervised learners of your choice, and the fourth algorithm is known as a *naive predictor*.

# %% [markdown]
# ### Metrics and the Naive Predictor
# *CharityML*, equipped with their research, knows individuals that make more than \$50,000 are most likely to donate to their charity. Because of this, *CharityML* is particularly interested in predicting who makes more than \$50,000 accurately. It would seem that using **accuracy** as a metric for evaluating a particular model's performace would be appropriate. Additionally, identifying someone that *does not* make more than \$50,000 as someone who does would be detrimental to *CharityML*, since they are looking to find individuals willing to donate. Therefore, a model's ability to precisely predict those that make more than \$50,000 is *more important* than the model's ability to **recall** those individuals. We can use **F-beta score** as a metric that considers both precision and recall:
#
# $$ F_{\beta} = (1 + \beta^2) \cdot \frac{precision \cdot recall}{\left( \beta^2 \cdot precision \right) + recall} $$
#
# In particular, when $\beta = 0.5$, more emphasis is placed on precision. This is called the **F$_{0.5}$ score** (or F-score for simplicity).
#
# Looking at the distribution of classes (those who make at most \$50,000, and those who make more), it's clear most individuals do not make more than \$50,000. This can greatly affect **accuracy**, since we could simply say *"this person does not make more than \$50,000"* and generally be right, without ever looking at the data! Making such a statement would be called **naive**, since we have not considered any information to substantiate the claim. It is always important to consider the *naive prediction* for your data, to help establish a benchmark for whether a model is performing well. That been said, using that prediction would be pointless: If we predicted all people made less than \$50,000, *CharityML* would identify no one as donors.
#
#
# #### Note: Recap of accuracy, precision, recall
#
# ** Accuracy ** measures how often the classifier makes the correct prediction. It’s the ratio of the number of correct predictions to the total number of predictions (the number of test data points).
#
# ** Precision ** tells us what proportion of messages we classified as spam, actually were spam.
# It is a ratio of true positives(words classified as spam, and which are actually spam) to all positives(all words classified as spam, irrespective of whether that was the correct classificatio), in other words it is the ratio of
#
# `[True Positives/(True Positives + False Positives)]`
#
# ** Recall(sensitivity)** tells us what proportion of messages that actually were spam were classified by us as spam.
# It is a ratio of true positives(words classified as spam, and which are actually spam) to all the words that were actually spam, in other words it is the ratio of
#
# `[True Positives/(True Positives + False Negatives)]`
#
# For classification problems that are skewed in their classification distributions like in our case, for example if we had a 100 text messages and only 2 were spam and the rest 98 weren't, accuracy by itself is not a very good metric. We could classify 90 messages as not spam(including the 2 that were spam but we classify them as not spam, hence they would be false negatives) and 10 as spam(all 10 false positives) and still get a reasonably good accuracy score. For such cases, precision and recall come in very handy. These two metrics can be combined to get the F1 score, which is weighted average(harmonic mean) of the precision and recall scores. This score can range from 0 to 1, with 1 being the best possible F1 score(we take the harmonic mean as we are dealing with ratios).

# %% [markdown]
# ### Question 1 - Naive Predictor Performace
# * If we chose a model that always predicted an individual made more than $50,000, what would  that model's accuracy and F-score be on this dataset? You must use the code cell below and assign your results to `'accuracy'` and `'fscore'` to be used later.
#
# ** Please note ** that the the purpose of generating a naive predictor is simply to show what a base model without any intelligence would look like. In the real world, ideally your base model would be either the results of a previous model or could be based on a research paper upon which you are looking to improve. When there is no benchmark model set, getting a result better than random choice is a place you could start from.
#
# ** HINT: **
#
# * When we have a model that always predicts '1' (i.e. the individual makes more than 50k) then our model will have no True Negatives(TN) or False Negatives(FN) as we are not making any negative('0' value) predictions. Therefore our Accuracy in this case becomes the same as our Precision(True Positives/(True Positives + False Positives)) as every prediction that we have made with value '1' that should have '0' becomes a False Positive; therefore our denominator in this case is the total number of records we have in total.
# * Our Recall score(True Positives/(True Positives + False Negatives)) in this setting becomes 1 as we have no False Negatives.

# %%
'''
TP = np.sum(income) # Counting the ones as this is the naive case. Note that 'income' is the 'income_raw' data 
encoded to numerical values done in the data preprocessing step.
FP = income.count() - TP # Specific to the naive case

TN = 0 # No predicted negatives in the naive case
FN = 0 # No predicted negatives in the naive case
'''
# TODO: Calculate accuracy, precision and recall
tp = np.sum(income)
fp = len(income) - tp
tn = 0
fn = 0

accuracy = (tp + tn) / (tp + fp + tn + fn)
recall = tp / (tp + fn)
precision = tp / (tp + fp)

# TODO: Calculate F-score using the formula above for beta = 0.5 and correct values for precision and recall.
beta = 0.5
fscore = (1 + 0.5**2) * ((precision * recall) / ((beta**2 * precision) + recall))

# Print the results 
print("Naive Predictor: [Accuracy score: {:.4f}, F-score: {:.4f}]".format(accuracy, fscore))
# Out:
# Naive Predictor: [Accuracy score: 0.2478, F-score: 0.2917]

# %% [markdown]
# ###  Supervised Learning Models
# **The following are some of the supervised learning models that are currently available in** [`scikit-learn`](http://scikit-learn.org/stable/supervised_learning.html) **that you may choose from:**
# - Gaussian Naive Bayes (GaussianNB)
# - Decision Trees
# - Ensemble Methods (Bagging, AdaBoost, Random Forest, Gradient Boosting)
# - K-Nearest Neighbors (KNeighbors)
# - Stochastic Gradient Descent Classifier (SGDC)
# - Support Vector Machines (SVM)
# - Logistic Regression

# %% [markdown]
# ### Question 2 - Model Application
# List three of the supervised learning models above that are appropriate for this problem that you will test on the census data. For each model chosen
#
# - Describe one real-world application in industry where the model can be applied.
# - What are the strengths of the model; when does it perform well?
# - What are the weaknesses of the model; when does it perform poorly?
# - What makes this model a good candidate for the problem, given what you know about the data?
#
# ** HINT: **
#
# Structure your answer in the same format as above^, with 4 parts for each of the three models you pick. Please include references with your answer.

# %% [markdown]
# **Answer: **
#
# ** Logistic Regression **
# * Model can be used to determine if an email is spam or not.
# * Logistic regression is understandable, easy to implement, fast to train and predict, and has nice probabilistic, interpretable results.
# * Logistic regression can underperform when there are multiple and/or non-linear decision boundaries.  Logistic regression can be prone to overfitting if using a large number of features.  It also isn't as strong as capturing complex relationships in the data.
# * I chose this model because it is a good, widely-used general-purpose classifier and will serve as a good baseline model to compare performance against.
#
# ** Support Vector Machine (SVM) **
# * Model can be used to determine if a subscription customer will churn.
# * SVM can model non-linear decision boundaries well.  It is also a flexible model with different kernels available (linear, poly, rbf) and hyperparameters to tune the margins.  It is also fairly robust against overfitting.
# * SVM is very computational intensive, especially in higher-dimension space.  It is slow in both training and prediction times.  If speed is important, SVM will not be a suitable model.  SVM is also a "black box" model in that the results are largely uninterpretable regarding feature importance.  It is also trickier to tune the hyperparameters and find the optimimal kernel, as opposed to other models that work much better "out of the box".
# *
#
# ** Gradient Boosting **
# * Model can be used to determine if a credit card transaction is fraudulent.
# * Gradient boosting is an ensemble model built off using a bunch of weak learning decision trees.  As an ensemble model, its strengths are its ability to limit variance and improve generalization over its base decision tree model.
# https://medium.com/@aravanshad/gradient-boosting-versus-random-forest-cfa3fa8f0d80
# * I choose this model because gradient boosting is known to work well with unbalanced data, which is the case here as less than 25% of the individuals in the data make more than \$50,000.

# %% [markdown]
# ### Implementation - Creating a Training and Predicting Pipeline
# To properly evaluate the performance of each model you've chosen, it's important that you create a training and predicting pipeline that allows you to quickly and effectively train models using various sizes of training data and perform predictions on the testing data. Your implementation here will be used in the following section.
# In the code block below, you will need to implement the following:
#  - Import `fbeta_score` and `accuracy_score` from [`sklearn.metrics`](http://scikit-learn.org/stable/modules/classes.html#sklearn-metrics-metrics).
#  - Fit the learner to the sampled training data and record the training time.
#  - Perform predictions on the test data `X_test`, and also on the first 300 training points `X_train[:300]`.
#    - Record the total prediction time.
#  - Calculate the accuracy score for both the training subset and testing set.
#  - Calculate the F-score for both the training subset and testing set.
#    - Make sure that you set the `beta` parameter!

# %%
# TODO: Import two metrics from sklearn - fbeta_score and accuracy_score
from sklearn.metrics import fbeta_score, accuracy_score

def train_predict(learner, sample_size, X_train, y_train, X_test, y_test): 
    '''
    inputs:
       - learner: the learning algorithm to be trained and predicted on
       - sample_size: the size of samples (number) to be drawn from training set
       - X_train: features training set
       - y_train: income training set
       - X_test: features testing set
       - y_test: income testing set
    '''
    
    results = {}
    
    # TODO: Fit the learner to the training data using slicing with 'sample_size' using .fit(training_features[:], training_labels[:])
    start = time() # Get start time
    learner = learner.fit(X_train[:sample_size], y_train[:sample_size])
    end = time() # Get end time
    
    # TODO: Calculate the training time
    results['train_time'] = end - start
        
    # TODO: Get the predictions on the test set(X_test),
    #       then get predictions on the first 300 training samples(X_train) using .predict()
    start = time() # Get start time
    predictions_test = learner.predict(X_test)
    predictions_train = learner.predict(X_train[:sample_size])
    end = time() # Get end time
    
    # TODO: Calculate the total prediction time
    results['pred_time'] = end - start
            
    # TODO: Compute accuracy on the first 300 training samples which is y_train[:300]
    results['acc_train'] = accuracy_score(y_train[:sample_size], predictions_train)
        
    # TODO: Compute accuracy on test set using accuracy_score()
    results['acc_test'] = accuracy_score(y_test, predictions_test)
    
    # TODO: Compute F-score on the the first 300 training samples using fbeta_score()
    results['f_train'] = fbeta_score(y_train[:sample_size], predictions_train, beta=0.5)
        
    # TODO: Compute F-score on the test set which is y_test
    results['f_test'] = fbeta_score(y_test, predictions_test, beta=0.5)
       
    # Success
    print("{} trained on {} samples.".format(learner.__class__.__name__, sample_size))
        
    # Return the results
    return results

# %% [markdown]
# ### Implementation: Initial Model Evaluation
# In the code cell, you will need to implement the following:
# - Import the three supervised learning models you've discussed in the previous section.
# - Initialize the three models and store them in `'clf_A'`, `'clf_B'`, and `'clf_C'`.
#   - Use a `'random_state'` for each model you use, if provided.
#   - **Note:** Use the default settings for each model — you will tune one specific model in a later section.
# - Calculate the number of records equal to 1%, 10%, and 100% of the training data.
#   - Store those values in `'samples_1'`, `'samples_10'`, and `'samples_100'` respectively.
#
# **Note:** Depending on which algorithms you chose, the following implementation may take some time to run!

# %%
# TODO: Import the three supervised learning models from sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC

# TODO: Initialize the three models
clf_A = LogisticRegression()
clf_B = SVC()
clf_C = GradientBoostingClassifier()

# TODO: Calculate the number of samples for 1%, 10%, and 100% of the training data
# HINT: samples_100 is the entire training set i.e. len(y_train)
# HINT: samples_10 is 10% of samples_100 (ensure to set the count of the values to be `int` and not `float`)
# HINT: samples_1 is 1% of samples_100 (ensure to set the count of the values to be `int` and not `float`)
samples_100 = len(y_train)
samples_10 = int(samples_100 / 10)
samples_1 = int(samples_100 / 100)

# Collect results on the learners
results = {}
for clf in [clf_A, clf_B, clf_C]:
    clf_name = clf.__class__.__name__
    results[clf_name] = {}
    for i, samples in enumerate([samples_1, samples_10, samples_100]):
        results[clf_name][i] = \
        train_predict(clf, samples, X_train, y_train, X_test, y_test)

# Run metrics visualization for the three supervised learning models chosen
vs.evaluate(results, accuracy, fscore)
# Out:
# LogisticRegression trained on 361 samples.
# LogisticRegression trained on 3617 samples.
# LogisticRegression trained on 36177 samples.
# C:\Users\kevin.lee\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# SVC trained on 361 samples.
# SVC trained on 3617 samples.
# SVC trained on 36177 samples.
# GradientBoostingClassifier trained on 361 samples.
# GradientBoostingClassifier trained on 3617 samples.
# GradientBoostingClassifier trained on 36177 samples.

# %% [markdown]
# ----
# ## Improving Results
# In this final section, you will choose from the three supervised learning models the *best* model to use on the student data. You will then perform a grid search optimization for the model over the entire training set (`X_train` and `y_train`) by tuning at least one parameter to improve upon the untuned model's F-score.

# %% [markdown]
# ### Question 3 - Choosing the Best Model
#
# * Based on the evaluation you performed earlier, in one to two paragraphs, explain to *CharityML* which of the three models you believe to be most appropriate for the task of identifying individuals that make more than \$50,000.
#
# ** HINT: **
# Look at the graph at the bottom left from the cell above(the visualization created by `vs.evaluate(results, accuracy, fscore)`) and check the F score for the testing set when 100% of the training set is used. Which model has the highest score? Your answer should include discussion of the:
# * metrics - F score on the testing when 100% of the training data is used,
# * prediction/training time
# * the algorithm's suitability for the data.

# %% [markdown]
# **Answer: **
# * In terms of f-score on the testing set, the three models consistently ranked the same across all sample sizes:
#     1. Gradient Boost
#     2. Logistic Regression
#     3. SVM
# * Prediction/Training/prediction time for logistic regression is very fast (less than one second), and while the gradient boost training time is magnitudes higher, it is still at a reasonable 10 seconds with a fast prediction time.  SVM has a very long training/prediction time, over 100 seconds for both.

# %% [markdown]
# ### Question 4 - Describing the Model in Layman's Terms
#
# * In one to two paragraphs, explain to *CharityML*, in layman's terms, how the final model chosen is supposed to work. Be sure that you are describing the major qualities of the model, such as how the model is trained and how the model makes a prediction. Avoid using advanced mathematical jargon, such as describing equations.
#
# ** HINT: **
#
# When explaining your model, if using external resources please include all citations.

# %% [markdown]
# **Answer: **
#
# ** Gradient Boosting **
# * Gradient boosting is built off using "weak learner" decision trees, which as essentially a predictor that performs slightly better than random.  At its core, the decision tree starts as a single node at the top, and then branches off into a number of solutions, with each split asking a fundamental question.  The overall graphical representation looks very much like a tree.
# * Tries to minimize
# * Each subsequent tree is built upon the prior tree's errors (boosting).

# %% [markdown]
# ### Implementation: Model Tuning
# Fine tune the chosen model. Use grid search (`GridSearchCV`) with at least one important parameter tuned with at least 3 different values. You will need to use the entire training set for this. In the code cell below, you will need to implement the following:
# - Import [`sklearn.grid_search.GridSearchCV`](http://scikit-learn.org/0.17/modules/generated/sklearn.grid_search.GridSearchCV.html) and [`sklearn.metrics.make_scorer`](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.make_scorer.html).
# - Initialize the classifier you've chosen and store it in `clf`.
#  - Set a `random_state` if one is available to the same state you set before.
# - Create a dictionary of parameters you wish to tune for the chosen model.
#  - Example: `parameters = {'parameter' : [list of values]}`.
#  - **Note:** Avoid tuning the `max_features` parameter of your learner if that parameter is available!
# - Use `make_scorer` to create an `fbeta_score` scoring object (with $\beta = 0.5$).
# - Perform grid search on the classifier `clf` using the `'scorer'`, and store it in `grid_obj`.
# - Fit the grid search object to the training data (`X_train`, `y_train`), and store it in `grid_fit`.
#
# **Note:** Depending on the algorithm chosen and the parameter list, the following implementation may take some time to run!

# %%
# TODO: Import 'GridSearchCV', 'make_scorer', and any other necessary libraries
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, make_scorer

# TODO: Initialize the classifier
clf = GradientBoostingClassifier()

# TODO: Create the parameters list you wish to tune, using a dictionary if needed.
# HINT: parameters = {'parameter_1': [value1, value2], 'parameter_2': [value1, value2]}
parameters = {'max_depth': [3,4,6], 'min_samples_split': [2,4,6],
              'min_samples_leaf': [1,2,4], 'learning_rate': [0.01,0.1,1]}

# TODO: Make an fbeta_score scoring object using make_scorer()
scorer = make_scorer(fbeta_score, beta=0.5)

# TODO: Perform grid search on the classifier using 'scorer' as the scoring method using GridSearchCV()
grid_obj = GridSearchCV(clf, parameters, scoring=scorer, cv=5, verbose=5)

# TODO: Fit the grid search object to the training data and find the optimal parameters using fit()
grid_fit = grid_obj.fit(X_train, y_train)

# Get the estimator
best_clf = grid_fit.best_estimator_

# Make predictions using the unoptimized and model
predictions = (clf.fit(X_train, y_train)).predict(X_test)
best_predictions = best_clf.predict(X_test)

# Report the before-and-afterscores
print("Unoptimized model\n------")
print("Accuracy score on testing data: {:.4f}".format(accuracy_score(y_test, predictions)))
print("F-score on testing data: {:.4f}".format(fbeta_score(y_test, predictions, beta = 0.5)))
print("\nOptimized Model\n------")
print("Final accuracy score on the testing data: {:.4f}".format(accuracy_score(y_test, best_predictions)))
print("Final F-score on the testing data: {:.4f}".format(fbeta_score(y_test, best_predictions, beta = 0.5)))
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, score=0.7009875344018132, total=  11.1s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   11.3s remaining:    0.0s
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, score=0.7229484958261143, total=  11.1s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   22.6s remaining:    0.0s
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, score=0.7021174972138194, total=  11.0s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   33.8s remaining:    0.0s
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, score=0.6961816984858459, total=  11.3s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   45.4s remaining:    0.0s
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, score=0.7181756296800546, total=  11.4s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4, score=0.7009875344018132, total=  11.2s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4, score=0.7229484958261143, total=  11.1s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4, score=0.7021174972138194, total=  11.0s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4, score=0.6961816984858459, total=  11.1s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4, score=0.7181756296800546, total=  11.6s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6, score=0.7009875344018132, total=  11.5s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6, score=0.7229484958261143, total=  16.3s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6, score=0.7021174972138194, total=  17.6s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6, score=0.6961816984858459, total=  13.3s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6, score=0.7181756296800546, total=  14.2s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, score=0.7009875344018132, total=  12.6s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, score=0.7229484958261143, total=  13.3s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, score=0.7021174972138194, total=  11.7s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, score=0.6961816984858459, total=  11.2s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, score=0.7181756296800546, total=  11.3s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4, score=0.7009875344018132, total=  11.4s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4, score=0.7229484958261143, total=  16.3s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4, score=0.7021174972138194, total=  22.4s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4, score=0.6961816984858459, total=  18.6s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4, score=0.7181756296800546, total=  20.9s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6, score=0.7009875344018132, total=  14.8s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6, score=0.7229484958261143, total=  12.6s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6, score=0.7021174972138194, total=  13.9s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6, score=0.6961816984858459, total=  15.4s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6, score=0.7181756296800546, total=  17.4s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2, score=0.7009875344018132, total=  15.1s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2, score=0.7229484958261143, total=  14.8s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2, score=0.7021174972138194, total=  13.5s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2, score=0.696546052631579, total=  14.0s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2, score=0.7181756296800546, total=  14.6s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4, score=0.7009875344018132, total=  16.5s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4, score=0.7229484958261143, total=  13.2s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4, score=0.7021174972138194, total=  13.1s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4, score=0.696546052631579, total=  14.5s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4, score=0.7181756296800546, total=  14.6s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6, score=0.7009875344018132, total=  14.2s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6, score=0.7229484958261143, total=  15.2s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6, score=0.7021174972138194, total=  14.5s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6, score=0.696546052631579, total=  19.1s
# [CV] learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6, score=0.7181756296800546, total=  16.4s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=2, score=0.7036973930822967, total=  19.8s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=2, score=0.7213167661771824, total=  20.6s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=2, score=0.7146520772781672, total=  19.5s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=2, score=0.6994733377221857, total=  19.2s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=2, score=0.7221254355400697, total=  17.7s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.7036973930822967, total=  18.7s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.7213167661771824, total=  19.7s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.7146520772781672, total=  17.6s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.6994733377221857, total=  18.0s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.7221254355400697, total=  17.1s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.7036973930822967, total=  17.0s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.7213167661771824, total=  18.2s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.7146520772781672, total=  16.8s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.6994733377221857, total=  17.1s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.7221254355400697, total=  16.5s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=2, score=0.7039619112395851, total=  16.9s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=2, score=0.7213167661771824, total=  17.0s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=2, score=0.7146520772781672, total=  16.6s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=2, score=0.699013157894737, total=  17.7s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=2, score=0.7221254355400697, total=  24.2s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=4, score=0.7039619112395851, total=  26.1s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=4, score=0.7213167661771824, total=  25.5s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=4, score=0.7146520772781672, total=  21.9s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=4, score=0.699013157894737, total=  21.0s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=4, score=0.7221254355400697, total=  18.3s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=6, score=0.7039619112395851, total=  19.0s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=6, score=0.7213167661771824, total=  18.9s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=6, score=0.7146520772781672, total=  20.5s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=6, score=0.699013157894737, total=  20.8s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=2, min_samples_split=6, score=0.7221254355400697, total=  23.0s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=2, score=0.7053469852104665, total=  26.9s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=2, score=0.7213167661771824, total=  26.1s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=2, score=0.7146520772781672, total=  18.7s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=2, score=0.699013157894737, total=  17.8s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=2, score=0.7216225626740946, total=  18.3s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=4, score=0.7053469852104665, total=  17.7s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=4, score=0.7213167661771824, total=  19.0s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=4, score=0.7146520772781672, total=  20.3s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=4, score=0.699013157894737, total=  20.3s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=4, score=0.7216225626740946, total=  17.4s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=6, score=0.7053469852104665, total=  18.2s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=6, score=0.7213167661771824, total=  17.2s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=6, score=0.7146520772781672, total=  17.1s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=6, score=0.699013157894737, total=  17.0s
# [CV] learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=4, min_samples_leaf=4, min_samples_split=6, score=0.7216225626740946, total=  16.8s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.7302081625962956, total=  32.0s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.7468515861629205, total=  34.2s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.7401837928153717, total=  34.2s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.7330588980367321, total=  33.3s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.75, total=  32.1s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.7302081625962956, total=  32.1s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.7468515861629205, total=  32.7s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.7408643417320205, total=  36.9s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.7330588980367321, total=  33.2s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.7486168741355463, total=  32.7s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.7302081625962956, total=  31.8s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.7471722160267642, total=  33.1s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.7408643417320205, total= 1.1min
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.7330588980367321, total=  40.6s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.74948132780083, total=  35.7s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=2, score=0.7306122448979594, total=  45.8s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=2, score=0.7462090981644055, total=  40.3s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=2, score=0.7390014829461197, total=  37.8s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=2, score=0.7337128399746995, total=  32.4s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=2, score=0.7505193905817175, total=  37.1s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=4, score=0.7306753458096013, total=  56.1s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=4, score=0.7465305471367043, total=  56.0s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=4, score=0.7390014829461197, total=  57.4s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=4, score=0.7337128399746995, total=  40.0s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=4, score=0.7505193905817175, total=  39.8s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=6, score=0.7306122448979594, total=  33.5s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=6, score=0.7473281225075769, total=  41.3s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=6, score=0.7414448669201521, total=  45.2s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=6, score=0.7337128399746995, total=  37.5s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=2, min_samples_split=6, score=0.75103591160221, total=  37.1s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=2, score=0.7312897440078265, total=  36.9s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=2, score=0.7465305471367043, total=  36.3s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=2, score=0.7410491257285595, total=  36.6s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=2, score=0.7341772151898734, total=  40.4s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=2, score=0.7501726519337016, total=  37.6s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=4, score=0.7312897440078265, total=  37.7s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=4, score=0.7465305471367043, total=  36.9s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=4, score=0.7410491257285595, total=  41.0s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=4, score=0.7341772151898734, total=  38.9s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=4, score=0.7501726519337016, total=  38.1s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=6, score=0.7312897440078265, total=  37.2s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=6, score=0.7465305471367043, total=  40.6s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=6, score=0.7410491257285595, total=  39.7s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=6, score=0.7341772151898734, total=  40.1s
# [CV] learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.01, max_depth=6, min_samples_leaf=4, min_samples_split=6, score=0.7501726519337016, total=  37.2s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, score=0.7320048800325336, total=  10.3s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, score=0.7613529173965772, total=  11.0s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, score=0.7442824662297711, total=   9.0s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, score=0.736088600756348, total=   9.8s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, score=0.752770083102493, total=  10.2s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4, score=0.7320048800325336, total=   9.6s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4, score=0.7606791537528635, total=   9.3s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4, score=0.7462686567164178, total=   9.5s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4, score=0.7370059556036817, total=   9.6s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4, score=0.7504168982768205, total=  15.1s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6, score=0.7343941248470012, total=  12.3s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6, score=0.7581612258494337, total=   9.6s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6, score=0.7462686567164178, total=   9.6s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6, score=0.737560843699297, total=   9.7s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6, score=0.7513812154696132, total=  10.4s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, score=0.7371141030871753, total=   8.8s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, score=0.7588510354041416, total=   8.6s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, score=0.7438516328450477, total=   9.6s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, score=0.7373709940249866, total=  10.2s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, score=0.7522062879205735, total=   9.3s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4, score=0.7371141030871753, total=   9.7s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4, score=0.7588510354041416, total=  10.4s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4, score=0.7438516328450477, total=   9.3s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4, score=0.7373709940249866, total=   9.0s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4, score=0.7522062879205735, total=  10.9s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6, score=0.7377381434941225, total=   9.9s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6, score=0.7624184312158742, total=   9.9s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6, score=0.7438516328450477, total=   9.5s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6, score=0.7402120717781403, total=   8.9s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6, score=0.7522062879205735, total=   8.6s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2, score=0.7347573340543464, total=   8.5s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2, score=0.7640479719714324, total=   8.3s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2, score=0.7434519811954332, total=  10.1s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2, score=0.7432249322493225, total=  11.2s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2, score=0.7527777777777779, total=  10.9s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4, score=0.7347573340543464, total=  12.4s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4, score=0.7640479719714324, total=  11.4s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4, score=0.7434519811954332, total=  10.1s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4, score=0.7432249322493225, total=   9.9s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4, score=0.7527777777777779, total=   9.9s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6, score=0.7347573340543464, total=   9.8s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6, score=0.7640479719714324, total=   9.8s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6, score=0.7434519811954332, total=   9.8s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6, score=0.7432249322493225, total=   9.7s
# [CV] learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6, score=0.7527777777777779, total=   9.9s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=2, score=0.7443070917371502, total=  15.4s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=2, score=0.7651544526302185, total=  14.3s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=2, score=0.7541899441340782, total=  13.0s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=2, score=0.7440789473684211, total=  13.2s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=2, score=0.7540512284370099, total=  13.5s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.747319467769022, total=  13.0s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.765379113018598, total=  18.0s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.7517187702685172, total=  16.3s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.7455097728473322, total=  15.2s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.7549894957983193, total=  15.1s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.7441830235278825, total=  14.6s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.7637185280826339, total=  14.0s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.754055807916937, total=  14.6s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.7424960505529226, total=  14.9s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.755249343832021, total=  13.2s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=2, score=0.7448194969373128, total=  15.6s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=2, score=0.7673999742699086, total=  13.2s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=2, score=0.7526254375729288, total=  14.5s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=2, score=0.7407651715039578, total=  16.2s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=2, score=0.7574152542372883, total=  13.7s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=4, score=0.7445560046942235, total=  13.3s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=4, score=0.7673999742699086, total=  13.0s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=4, score=0.7526254375729288, total=  13.3s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=4, score=0.7407651715039578, total=  13.1s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=4, score=0.7574152542372883, total=  13.2s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=6, score=0.7455968688845402, total=  13.5s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=6, score=0.7671957671957671, total=  12.8s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=6, score=0.7532907598071158, total=  13.0s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=6, score=0.7424762407602957, total=  13.1s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=2, min_samples_split=6, score=0.756440588853838, total=  13.4s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=2, score=0.7475665152498377, total=  13.1s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=2, score=0.7626464152400567, total=  13.1s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=2, score=0.7509419254254905, total=  13.1s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=2, score=0.7453703703703703, total=  13.2s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=2, score=0.7541972717733474, total=  13.2s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=4, score=0.7475665152498377, total=  13.2s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=4, score=0.7626464152400567, total=  13.0s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=4, score=0.7509419254254905, total=  13.3s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=4, score=0.7453703703703703, total=  13.2s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=4, score=0.7541972717733474, total=  13.2s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=6, score=0.7475665152498377, total=  13.1s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=6, score=0.7626464152400567, total=  13.1s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=6, score=0.7509419254254905, total=  13.1s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=6, score=0.7453703703703703, total=  13.2s
# [CV] learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=4, min_samples_leaf=4, min_samples_split=6, score=0.7541972717733474, total=  13.3s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.7523133476993282, total=  25.7s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.7609103413780166, total=  26.9s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.7548450808542154, total=  29.1s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.751953125, total=  28.9s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.7498715973292245, total=  28.9s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.7501585288522511, total=  30.9s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.7570268582136165, total=  31.5s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.7565337001375515, total=  31.4s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.7510449320794148, total=  36.0s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.7541004613018965, total=  33.0s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.7509157509157509, total=  34.9s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.7579171360620853, total=  30.4s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.7542700411420021, total=  28.2s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.7485766045548654, total=  33.0s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=0.1, max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.7537332646755922, total=  34.8s
# [CV] learning_rate=0.1, max_depth=6, min_samples_leaf=2, min_samples_split=2
# ...
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.7288575667655787, total=  11.2s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.7228389671947113, total=  10.0s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.7456301185674122, total=   8.7s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.732945400519995, total=   9.2s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.7236187157789945, total=  10.0s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.7259050880626223, total=  12.5s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=2, score=0.7200936306517187, total=  13.5s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=2, score=0.7397310069065794, total=  11.0s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=2, score=0.7347363269301358, total=  10.1s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=2, score=0.7207262845849801, total=  10.9s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=2, score=0.716367168528412, total=  11.0s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=4, score=0.7204486626402071, total=  11.1s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=4, score=0.7397310069065794, total=  11.4s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=4, score=0.7349883820472056, total=   9.8s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=4, score=0.7200148075024679, total=  11.0s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=4, score=0.7262941461054668, total=  11.3s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=6, score=0.7333085593955158, total=   9.2s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=6, score=0.7343542746894972, total=  10.0s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=6, score=0.7320189850310332, total=   8.6s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=6, score=0.7307401812688822, total=   9.8s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=2, min_samples_split=6, score=0.7259050880626223, total=  11.6s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=2, score=0.7209473555037428, total=  11.2s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=2, score=0.7350272232304901, total=   9.7s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=2, score=0.722026056252283, total=  11.1s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=2, score=0.7265117441279361, total=  11.7s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=2, score=0.7308541973490426, total=  12.9s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=4, score=0.7209473555037428, total=  13.4s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=4, score=0.7350272232304901, total=   9.8s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=4, score=0.722026056252283, total=   9.0s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=4, score=0.7265117441279361, total=   9.8s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=4, score=0.7308541973490426, total=  11.0s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=6, score=0.7209473555037428, total=  12.0s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=6, score=0.7387398324632755, total=  11.4s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=6, score=0.722026056252283, total=  10.3s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=6, score=0.7265117441279361, total=  10.9s
# [CV] learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=1, max_depth=4, min_samples_leaf=4, min_samples_split=6, score=0.7308541973490426, total=  11.2s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.692064649410621, total=  24.7s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.6999416228838296, total=  27.6s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.6885877818011915, total=  31.9s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.6870860927152317, total=  24.6s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=2
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.6995958155016643, total=  24.5s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.7059831151352012, total=  17.3s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.7046547074686363, total=  21.5s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.6897545234528062, total=  23.5s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.7019002375296912, total=  18.4s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=4
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.7029369282619161, total=  22.5s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.7113301691614945, total=  20.4s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.7275523482787177, total=  16.0s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.7034466533349019, total=  27.2s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.7040299227799228, total=  30.2s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=6
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.6986350574712643, total=  35.1s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=2, score=0.7142857142857143, total=  22.4s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=2, score=0.7093590200975147, total=  21.1s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=2, score=0.7115545465408055, total=  17.3s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=2, score=0.6954393505253105, total=  20.3s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=2
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=2, score=0.7102409638554218, total=  18.2s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=4, score=0.7154291343430612, total=  18.3s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=4, score=0.7087644190748007, total=  19.1s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=4, score=0.6926610908234185, total=  23.1s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=4, score=0.7080504364694471, total=  20.1s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=4
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=4, score=0.7029002876318312, total=  22.4s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=6, score=0.6827164929931728, total=  34.5s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=6, score=0.7137796670208998, total=  19.9s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=6, score=0.7142857142857144, total=  17.5s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=6, score=0.7204011741682974, total=  15.3s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=6
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=2, min_samples_split=6, score=0.7137663596703828, total=  17.3s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=2, score=0.7118457972428938, total=  15.8s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=2, score=0.7263533610945866, total=  16.4s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=2, score=0.7078545196066817, total=  15.1s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=2, score=0.7262258543833582, total=  21.2s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=2
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=2, score=0.716893865628043, total=  17.0s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=4, score=0.7121933357744415, total=  14.2s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=4, score=0.7018460466736329, total=  17.2s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=4, score=0.708190114969776, total=  14.2s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=4, score=0.7262258543833582, total=  17.9s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=4
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=4, score=0.7170731707317073, total=  17.7s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=6, score=0.7121933357744415, total=  14.4s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=6, score=0.7160435954529474, total=  16.3s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=6, score=0.708190114969776, total=  14.2s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=6, score=0.7262258543833582, total=  15.7s
# [CV] learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=6
# [CV]  learning_rate=1, max_depth=6, min_samples_leaf=4, min_samples_split=6, score=0.7238442822384428, total=  16.1s
# [Parallel(n_jobs=1)]: Done 405 out of 405 | elapsed: 126.2min finished
# Unoptimized model
# ------
# Accuracy score on testing data: 0.8630
# F-score on testing data: 0.7395
#
# Optimized Model
# ------
# Final accuracy score on the testing data: 0.8710
# Final F-score on the testing data: 0.7522

# %%
grid_fit.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 6,
#  'min_samples_leaf': 4,
#  'min_samples_split': 6}

# %% [markdown]
# ### Question 5 - Final Model Evaluation
#
# * What is your optimized model's accuracy and F-score on the testing data?
# * Are these scores better or worse than the unoptimized model?
# * How do the results from your optimized model compare to the naive predictor benchmarks you found earlier in **Question 1**?_
#
# **Note:** Fill in the table below with your results, and then provide discussion in the **Answer** box.

# %% [markdown]
# #### Results:
#
# |     Metric     |  Naive Model  | Unoptimized Model | Optimized Model |
# | :------------: | :---------------: | :-------------: |
# | Accuracy Score |        0.2478           |        0.8630           |     **0.8710**           |
# | F-score        |        0.2917           |        0.7395           |   **0.7522**      |

# %% [markdown]
# **Answer: **
# * The f-beta score and the accuracy for the optimized model is slightly better than the unoptimized model, which is what we would hope.  Perhaps tuning different hyperparameters or narrowing downthe ideal hyperparameter values could increase perfomance even more.  Probably the better option would be to do more feature engineering to improve performance.
# * The optimized model decisively outperforms the naive model.

# %% [markdown]
# ----
# ## Feature Importance
#
# An important task when performing supervised learning on a dataset like the census data we study here is determining which features provide the most predictive power. By focusing on the relationship between only a few crucial features and the target label we simplify our understanding of the phenomenon, which is most always a useful thing to do. In the case of this project, that means we wish to identify a small number of features that most strongly predict whether an individual makes at most or more than \$50,000.
#
# Choose a scikit-learn classifier (e.g., adaboost, random forests) that has a `feature_importance_` attribute, which is a function that ranks the importance of features according to the chosen classifier.  In the next python cell fit this classifier to training set and use this attribute to determine the top 5 most important features for the census dataset.

# %% [markdown]
# ### Question 6 - Feature Relevance Observation
# When **Exploring the Data**, it was shown there are thirteen available features for each individual on record in the census data. Of these thirteen records, which five features do you believe to be most important for prediction, and in what order would you rank them and why?

# %% [markdown]
# **Answer:**
# * occupation: Occupation is a strong indicator of earnings and encompasses many important characteristics like experience, education, skillset, etc.
# * education-num: In general, as education increases, average earnings increases as well.  I picked the numerical version as this normalizes the education data into one feature, rather than having 16 categorical yes/no features.
# * capital-gain: Capital gain is strongly correlated to earnings, the more earnings you have, the higher your reported capital gains are.
# * hours-per-week: More hours leads to more money, high demanding jobs generally pay well. This feature will also weed out part-time workers.
# * age: On average, earnings increase as age increases until 50+ years old.  People gain more experience and advance to senior positions as time goes on up until the point where people start to be replaced/retire.

# %% [markdown]
# ### Implementation - Extracting Feature Importance
# Choose a `scikit-learn` supervised learning algorithm that has a `feature_importance_` attribute availble for it. This attribute is a function that ranks the importance of each feature when making predictions based on the chosen algorithm.
#
# In the code cell below, you will need to implement the following:
#  - Import a supervised learning model from sklearn if it is different from the three used earlier.
#  - Train the supervised model on the entire training set.
#  - Extract the feature importances using `'.feature_importances_'`.

# %%
# TODO: Import a supervised learning model that has 'feature_importances_'
clf_fi = RandomForestClassifier()

# TODO: Train the supervised model on the training set using .fit(X_train, y_train)
model = clf_fi.fit(X_train, y_train)

# TODO: Extract the feature importances using .feature_importances_ 
importances = clf_fi.feature_importances_

# Plot
vs.feature_plot(importances, X_train, y_train)

# %% [markdown]
# ### Question 7 - Extracting Feature Importance
#
# Observe the visualization created above which displays the five most relevant features for predicting if an individual makes at most or above \$50,000.
# * How do these five features compare to the five features you discussed in **Question 6**?
# * If you were close to the same answer, how does this visualization confirm your thoughts?
# * If you were not close, why do you think these features are more relevant?

# %% [markdown]
# **Answer:**
# * These five features match closely with what I discussed in Question 6.  Interestingly, my top choice, occupation, is not within the top 5 feature importances from the random forest model.  However, the other 4 are.
# * The visualization clearly shows the top 5 feature importances with
# * Perhaps the occupation feature did not score a high importance because it was split up into a bunch of binary features because of using "get_dummies", one for each occupation type.  The feature I missed is "marital-status_Married-civ-spouse"

# %% [markdown]
# ### Feature Selection
# How does a model perform if we only use a subset of all the available features in the data? With less features required to train, the expectation is that training and prediction time is much lower — at the cost of performance metrics. From the visualization above, we see that the top five most important features contribute more than half of the importance of **all** features present in the data. This hints that we can attempt to *reduce the feature space* and simplify the information required for the model to learn. The code cell below will use the same optimized model you found earlier, and train it on the same training set *with only the top five important features*.

# %%
# Import functionality for cloning a model
from sklearn.base import clone

# Reduce the feature space
X_train_reduced = X_train[X_train.columns.values[(np.argsort(importances)[::-1])[:5]]]
X_test_reduced = X_test[X_test.columns.values[(np.argsort(importances)[::-1])[:5]]]

# Train on the "best" model found from grid search earlier
clf = (clone(best_clf)).fit(X_train_reduced, y_train)

# Make new predictions
reduced_predictions = clf.predict(X_test_reduced)

# Report scores from the final model using both versions of data
print("Final Model trained on full data\n------")
print("Accuracy on testing data: {:.4f}".format(accuracy_score(y_test, best_predictions)))
print("F-score on testing data: {:.4f}".format(fbeta_score(y_test, best_predictions, beta = 0.5)))
print("\nFinal Model trained on reduced data\n------")
print("Accuracy on testing data: {:.4f}".format(accuracy_score(y_test, reduced_predictions)))
print("F-score on testing data: {:.4f}".format(fbeta_score(y_test, reduced_predictions, beta = 0.5)))
# Out:
# Final Model trained on full data
# ------
# Accuracy on testing data: 0.8687
# F-score on testing data: 0.7467
#
# Final Model trained on reduced data
# ------
# Accuracy on testing data: 0.8499
# F-score on testing data: 0.7023

# %% [markdown]
# ### Question 8 - Effects of Feature Selection
#
# * How does the final model's F-score and accuracy score on the reduced data using only five features compare to those same scores when all features are used?
# * If training time was a factor, would you consider using the reduced data as your training set?

# %% [markdown]
# **Answer:**
# * The feature selection model performs worse on the testing set with an f-score of 0.7023 compared to the full feature model with a score of 0.7467.  This decrease makes sense as cutting features will lose some information.  But given that full feature set has 103 features, using less than 5% of those features and still obtaining a fairly strong f-score is pretty impressive.
# * Training time should always be considered as a factor, if the model requires split-second real-time training, then perhaps the tradoff of speed is worth the decrease in performance.  However, if training time is unimportant, then perhaps maximizing performance is best.  We could also test taking the top 10 or 20 features, using PCA, or using L1 regularization to have the algorithm do feature selection.  It is all about a matter of balance and context.

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to
# **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
